# %% [markdown]
# # Identify procedural reasons for 'all-nothing-all' mutations
# ## April 4, 2017
#
# Mutations that have 100% frequency in one generation, disappear completely (0%) in the next generation sampled, then reappear at 100% frequency. Potential explanations:
#
# 1. Biological - Frequency-dependent selection?
# 2. Procedural - Undersampled populations? Missing coverage during sequencing? Breseq frequency threshold for polymorphism mode (5-95%) not met?
#
# Input:
# 1. HTML file from gdtools COMPARE
# 2. GD files (annotated.gd) from breseq output.
#
# Tasks:
# 1. Identify rows with 'all-nothing-all' (a-n-a) pattern in input HTML file, by mutation position.
# 2. For each a-n-a, identify mutation position and generation(s) when 0% frequency occurs.
# 3. For each 0% frequency occurrence in a-n-a, refer to relevant annotated.gd file to identify reason for frequency.
# 4. Classify procedural reasons, summary counts.

# %%
from bs4 import BeautifulSoup
ua3 = BeautifulSoup(open('/Users/ymseah/Documents/compare/UA3.html'), 'html.parser')

# %%
ua3.contents
# Out:
# ['html\nPUBLIC "-//W3C//DTD XHTML 1.0 Transitional//EN"\n"http://www.w3.org/TR/xhtml1/DTD/xhtml1-transitional.dtd"',
#  '\n',
#  <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
#  <html>
#  <head>
#  <title>Mutation Comparison</title>
#  <style type="text/css">
#  body {font-family: sans-serif; font-size: 11pt;}
#  th {background-color: rgb(0,0,0); color: rgb(255,255,255);}
#  table {background-color: rgb(1,0,0); color: rgb(0,0,0);}
#  tr {background-color: rgb(255,255,255);}
#  .mutation_in_codon {color:red; text-decoration : underline;}
#  .snp_type_synonymous{color:green;}
#  .snp_type_nonsynonymous{color:blue;}
#  .snp_type_nonsense{color:red;}
#  .mutation_header_row {background-color: rgb(0,130,0);}
#  .read_alignment_header_row {background-color: rgb(255,0,0);}
#  .missing_coverage_header_row {background-color: rgb(0,100,100);}
#  .new_junction_header_row {background-color: rgb(0,0,155);}
#  .copy_number_header_row {background-color: rgb(153,102,0);}
#  .alternate_table_row_0 {background-color: rgb(255,255,255);}
#  .alternate_table_row_1 {background-color: rgb(235,235,235);}
#  .gray_table_row {background-color: rgb(230,230,245);}
#  .polymorphism_table_row {background-color: rgb(160,255,160);}
#  .highlight_table_row {background-color: rgb(192,255,255);}
#  .reject_table_row {background-color: rgb(255,200,165);}
#  .user_defined_table_row {background-color: rgb(255,255,0);}
#  .information_table_row {background-color: rgb(200,255,255);}
#  .junction_repeat {background-color: rgb(255,165,0)}
#  .junction_gene {}
#  .hidden { display: none; }
#  .unhidden { display: block; }
#
#  </style>
#  <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#  <script type="text/javascript">
#    function hideTog(divID) {
#      var item = document.getElementById(divID);
#      if (item) {
#        item.className=(item.className=='hidden')?'unhidden':'hidden';
#      }
#    }
#    function showTog(butID) {
#      var button = document.getElementById(butID);
#      if (button) {
#        button.value=(button.value=='Show')?'Hide':'Show';
#      }
#    }
#  </script>
#  </head>
#  <body>
#  <!--Output Html_Mutation_Table_String-->
#  <table border="0" cellpadding="3" cellspacing="1">
#  <tr><th align="left" class="mutation_header_row" colspan="12">Predicted mutations</th></tr><tr>
#  <th>seq id</th>
#  <th>position</th>
#  <th>mutation</th>
#  <th>0</th>
#  <th>UA3-100</th>
#  <th>UA3-300</th>
#  <th>UA3-500</th>
#  <th>UA3-780</th>
#  <th>UA3-1000</th>
#  <th>annotation</th>
#  <th>gene</th>
#  <th width="100%">description</th>
#  </tr>
#  <!-- Item Lines -->
#  <!-- Print The Table Row -->
#  <tr class="alternate_table_row_1">
#  <td align="center">NC_002937</td><!-- Seq_Id -->
#  <td align="right">5,565</td><!-- Position -->
#  <td align="center">G→A</td><!-- Cell Mutation -->
#  <td align="right">100%</td><td align="right"></td><td align="right">16.9%</td><td align="right"></td><td align="right"></td><td align="right"></td>
#  <td align="center"><font class="snp_type_nonsynonymous">D102N</font> (<font class="mutation_in_codon">G</font>AC→<font class="mutation_in_codon">A</font>AC) </td>
#  <td align="center"><i>gyrA</i> →</td>
#  <td align="left">DNA gyrase subunit A</td>
#  </tr>
#  <!-- End Table Row -->
#  <!-- Print The Table Row -->
#  <tr class="alternate_table_row_0">
#  <td align="center">NC_002937</td><!-- Seq_Id -->
#  <td align="right
bp</td><!-- Cell Mutation -->
#  <td align="right"></td><td align="right"></td><td align="right"></td><td align="right"></td><td align="right">7.1%</td><td align="right"></td>
#  <td align="center">intergenic (‑122/+332)</td>
#  <td align="center"><i>DVU0174</i> ← / ← <i>DVU0175</i></td>
#  <td align="left">hypothetical protein/tungsten formylmethanofuran dehydrogenase/molybdopterin binding protein</td>
#  </tr>
#  <!-- End Table Row -->
#  <!-- Print The Table Row -->
#  <tr class="alternate_table_row_0">
#  <td align="center">NC_002937</td><!-- Seq_Id -->
#  <td align="right">218,904</td><!-- Position -->
#  <td align="center">Δ24 bp</td><!-- Cell Mutation -->
#  <td align="right"></td><td align="right"></td><td align="right">5.2%</td><td align="right"></td><td align="right"></td><td align="right"></td>
#  <td align="center">intergenic (‑123/+331)</td>
#  <td align="center"><i>DVU0174</i> ← / ← <i>DVU0175</i></td>
#  <td align="left">hypothetical protein/tungsten formylmethanofuran dehydrogenase/molybdopterin binding protein</td>
#  </tr>
#  <!-- End Table Row -->
#  <!-- Print The Table Row -->
#  <tr class="alternate_table_row_1">
#  <td align="center">NC_002937</td><!-- Seq_Id -->
#  <td align="right">229,814</td><!-- Position -->
#  <td align="center">A→G</td><!-- Cell Mutation -->
#  <td align="right"></td><td align="right"></td><td align="right"></td><td align="right"></td><td align="right"></td><td align="right">67.2%</td>
#  <td align="center"><font class="snp_type_nonsynonymous">K137R</font> (A<font class="mutation_in_codon">A</font>A→A<font class="mutation_in_codon">G</font>A) </td>
#  <td align="center"><i>DVU0184</i> →</td>
#  <td align="left">hypothetical protein</td>
#  </tr>
#  <!-- End Table Row -->
#  <!-- Print The Table Row -->
#  <tr class="alternate_table_row_0">
#  <td align="center">NC_002937</td><!-- Seq_Id -->
#  <td align="right">242,278</td><!-- Position -->
#  <td align="center">Δ9 bp</td><!-- Cell Mutation -->
#  <td align="right"></td><td align="right">?</td><td align="right">8.7%</td><td align="right"></td><td align="right"></td><td align="right"></td>
#  <td align="center">coding (88‑96/396 nt)</td>
#  <td align="center"><i>DVU0196</i> →</td>
#  <td align="left">hypothetical protein</td>
#  </tr>
#  <!-- End Table Row -->
#  <!-- Print The Table Row -->
#  <tr class="alternate_table_row_1">
#  <td align="center">NC_002937</td><!-- Seq_Id -->
#  <td align="right">245,396</td><!-- Position -->
#  <td align="center">C→A</td><!-- Cell Mutation -->
#  <td align="right">11.9%</td><td align="right">?</td><td align="right"></td><td align="right"></td><td align="right"></td><td align="right"></td>
#  <td align="center"><font class="snp_type_nonsynonymous">L375M</font> (<font class="mutation_in_codon">C</font>TG→<font class="mutation_in_codon">A</font>TG) </td>
#  <td align="center"><i>DVU0198</i> →</td>
#  <td align="left">minor capsid protein C, degenerate</td>
#  </tr>
#  <!-- End Table Row -->
#  <!-- Print The Table Row -->
#  <tr class="alternate_table_row_0">
#  <td align="center">NC_002937</td><!-- Seq_Id -->
#  <td align="right">245,398</td><!-- Position -->
#  <td align="center">G→C</td><!-- Cell Mutation -->
#  <td align="right">14.3%</td><td align="right">?</td><td align="right"></td><td align="right"></td><td align="right"></td><td align="right"></td>
#  <td align="center"><font class="snp_type_synonymous">L375L</font> (CT<font class="mutation_in_codon">G</font>→CT<font class="mutation_in_codon">C</font>) </td>
#  <td align="center"><i>DVU0198</i> →</td>
#  <td align="left">minor capsid protein C, degenerate</td>
#  </tr>
#  <!-- End Table Row -->
#  <tr>
#  <th>seq id</th>
#  <th>position</th>
#  <th>mutation</th>
#  <th>0</th>
#  <th>UA3-100</th>
#  <th>UA3-300</th>
#  <th>UA3-500</th>
#  <th>UA3-780</th>
#  <th>UA3-1000</th>
#  <th>annotation</th>
#  <th>gene</th>
#  <th width="100%">description</th>
#  </tr>
#  <!-- Print The Table Row -->
#  <tr class="alternate_table_row_1">
#  <td align="center">NC_002937</td><!-- Seq_Id -->
#  <td align="right">245,400</td><!-- Position -->
#  <td align="center">T→A</td><!-- Cell Mutation -->
#  <td align="right">16.6%</td><td align="right">?</td><td align="right"></td><td align="right"></td><td align="right"></td><td align="right"></td>
#  <td align="center"><font class="snp_type_nonsynonymous">L376Q</font> (C<font class="mutation_in_codon">T</font>G→C<font class="mutation_in_codon">A</font>G) </td>
#  <td align="center"><i>DVU0198</i> →</td>
#  <td align="left">minor capsid protein C, degenerate</td>
#  </tr>
#  <!-- End Table Row -->
#  <!-- Print The Table Row -->
#  <tr class="alternate_table_row_0">
#  <td align="center">NC_002937</td><!-- Seq_Id -->
#  <td align="right">251,228</td><!-- Position -->
#  <td align="center">Δ48 bp</td><!-- Cell Mutation -->
#  <td align="right"></td><td align="right"></td><td align="right"></td><td align="right"></td><td align="right">5.3%</td><td align="right"></td>
#  <td align="center">coding (598‑645/1464 nt)</td>
#  <td align="center"><i>DVU0210</i> →</td>
#  <td align="left">tail sheath protein</td>
#  </tr>
#  <!-- End Table Row -->
#  <!-- Print The Table Row -->
#  <tr class="alternate_table_row_1">
#  <td align="center">NC_002937</td><!-- Seq_Id -->
#  <td align="right">318,881</td><!-- Position -->
#  <td align="center">Δ80 bp</td><!-- Cell Mutation -->
#  <td align="right">11.6%</td><td align="right"></td><td align="right"></td><td align="right">12.7%</td><td align="right">8.6%</td><td align="right"></td>
#  <td align="center"></td>
#  <td align="center"><i>[DVU_tRNA‑Val‑1]</i>–<i>[DVU_tRNA‑Asp‑1]</i></td>
#  <td align="left"><i>[DVU_tRNA‑Val‑1], [DVU_tRNA‑Asp‑1]</i></td>
#  </tr>
#  <!-- End Table Row -->
#  <!-- Print The Table Row -->
#  <tr class="alternate_table_row_0">
#  <td align="center">NC_002937</td><!-- Seq_Id -->
#  <td align="right">338,804</td><!-- Position -->
#  <td align="center">Δ85 bp</td><!-- Cell Mutation -->
#  <td align="right"></td><td align="right">?</td><td align="right">10.1%</td><td align="right"></td><td align="right">11.0%</td><td align="right"></td>
#  <td align="center">coding (623‑707/2145 nt)</td>
#  <td align="center"><i>DVU0294</i> →</td>
#  <td align="left">glycosyl transferase group 2 family protein</td>
#  </tr>
#  <!-- End Table Row -->
#  <!-- Print The Table Row -->
#  <tr class="alternate_table_row_1">
#  <td align="center">NC_002937</td><!-- Seq_Id -->
#  <td align="right">390,715</td><!-- Position -->
#  <td align="center">Δ30 bp</td><!-- Cell Mutation -->
#  <td align="right"></td><td align="right"></td><td align="right">8.5%</td><td align="right"></td><td align="right"></td><td align="right"></td>
#  <td align="center">coding (854‑883/1929 nt)</td>
#  <td align="center"><i>DVU0344</i> ←</td>
#  <td align="left">methyl‑accepting chemotaxis protein</td>
#  </tr>
#  <!-- End Table Row -->
#  <!-- Print The Table Row -->
#  <tr class="alternate_table_row_0">
#  <td align="center">NC_002937</td><!-- Seq_Id -->
#  <td align="right">411,732</td><!-- Position -->
#  <td align="center">Δ72 bp</td><!-- Cell Mutation -->
#  <td align="right"></td><td align="right"></td><td align="right">5.4%</td><td align="right"></td><td align="right"></td><td align="right"></td>
#  <td align="center">coding (438‑509/780 nt)</td>
#  <td align="center"><i>DVU0362</i> ←</td>
#  <td align="left">hypothetical protein</td>
#  </tr>
#  <!-- End Table Row -->
#  <!-- Print The Table Row -->
#  <tr class="alternate_table_row_1">
#  <td align="center">NC_002937</td><!-- Seq_Id -->
#  <td align="right">418,031</td><!-- Position -->
#  <td align="center">Δ54 bp</td><!-- Cell Mutation -->
#  <td align="right"></td><td align="right"></td><td align="right"></td><td align="
</td><td align="right"></td><td align="right"></td><td align="right"></td>
#  <td align="center">coding (1745‑1774/3384 nt)</td>
#  <td align="center"><i>DVU0453</i> →</td>
#  <td align="left">ATP‑dependent DNA helicase UvrD</td>
#  </tr>
#  <!-- End Table Row -->
#  <!-- Print The Table Row -->
#  <tr class="alternate_table_row_0">
#  <td align="center">NC_002937</td><!-- Seq_Id -->
#  <td align="right">533,613</td><!-- Position -->
#  <td align="center">Δ48 bp</td><!-- Cell Mutation -->
#  <td align="right"></td><td align="right"></td><td align="right">5.9%</td><td align="right"></td><td align="right"></td><td align="right"></td>
#  <td align="center">coding (761‑808/1599 nt)</td>
#  <td align="center"><i>DVU0465</i> →</td>
#  <td align="left">anthranilate synthase, component I</td>
#  </tr>
#  <!-- End Table Row -->
#  <!-- Print The Table Row -->
#  <tr class="alternate_table_row_1">
#  <td align="center">NC_002937</td><!-- Seq_Id -->
#  <td align="right">535,116</td><!-- Position -->
#  <td align="center">Δ51 bp</td><!-- Cell Mutation -->
#  <td align="right"></td><td align="right"></td><td align="right"></td><td align="right"></td><td align="right">7.0%</td><td align="right"></td>
#  <td align="center">coding (59‑109/999 nt)</td>
#  <td align="center"><i>trpD</i> →</td>
#  <td align="left">anthranilate phosphoribosyltransferase</td>
#  </tr>
#  <!-- End Table Row -->
#  <!-- Print The Table Row -->
#  <tr class="alternate_table_row_0">
#  <td align="center">NC_002937</td><!-- Seq_Id -->
#  <td align="right">544,137</td><!-- Position -->
#  <td align="center">Δ48 bp</td><!-- Cell Mutation -->
#  <td align="right"></td><td align="right">?</td><td align="right"></td><td align="right"></td><td align="right"></td><td align="right">8.8%</td>
#  <td align="center">coding (530‑577/864 nt)</td>
#  <td align="center"><i>DVU0478</i> →</td>
#  <td align="left">serine/threonine protein phosphatase</td>
#  </tr>
#  <!-- End Table Row -->
#  <!-- Print The Table Row -->
#  <tr class="alternate_table_row_1">
#  <td align="center">NC_002937</td><!-- Seq_Id -->
#  <td align="right">618,373</td><!-- Position -->
#  <td align="center">Δ63 bp</td><!-- Cell Mutation -->
#  <td align="right"></td><td align="right"></td><td align="right"></td><td align="right"></td><td align="right"></td><td align="right">8.0%</td>
#  <td align="center">coding (156‑218/909 nt)</td>
#  <td align="center"><i>DVU0548</i> →</td>
#  <td align="left">high‑affinity branched‑chain amino acid ABC transporter permease</td>
#  </tr>
#  <!-- End Table Row -->
#  <!-- Print The Table Row -->
#  <tr class="alternate_table_row_0">
#  <td align="center">NC_002937</td><!-- Seq_Id -->
#  <td align="right">629,936</td><!-- Position -->
#  <td align="center">IS<i>D1</i> (–) +4 bp</td><!-- Cell Mutation -->
#  <td align="right">100%</td><td align="right">100%</td><td align="right">100%</td><td align="right">100%</td><td align="right"></td><td align="right">100%</td>
#  <td align="center">intergenic (‑61/+148)</td>
#  <td align="center"><i>DVU0564</i> ← / ← <i>gap‑1</i></td>
#  <td align="left">ISDvu4, transposase, truncation/glyceraldehyde 3‑phosphate dehydrogenase</td>
#  </tr>
#  <!-- End Table Row -->
#  <!-- Print The Table Row -->
#  <tr class="alternate_table_row_1">
#  <td align="center">NC_002937</td><!-- Seq_Id -->
#  <td align="right">666,321</td><!-- Position -->
#  <td align="center">A→C</td><!-- Cell Mutation -->
#  <td align="right"></td><td align="right"></td><td align="right"></td><td align="right"></td><td align="right">56.7%</td><td align="right">100%</td>
#  <td align="center"><font class="snp_type_nonsynonymous">K317N</font> (AA<font class="mutation_in_codon">A</font>→AA<font class="mutation_in_codon">C</font>) </td>
#  <td align="center"><i>lytS</i> →</td>
#  <td align="left">regulatory protein LytS</td>
#  </tr>
#  <!-- End Table Row -->
#  <!-- Print The Table Row -->
#  <tr class="alternate_table_row_0">
#  <td align="center">NC_002937</td><!-- Seq_Id -->
#  <td align="right">677,651</td><!-- Position -->
#  <td align="center">Δ21 bp</td><!-- Cell Mutation -->
#  <td align="right">7.7%</td><td align="right"></td><td align="right"></td><td align="right"></td><td align="right"></td><td align="right"></td>
#  <td align="center">coding (1114‑1134/2034 nt)</td>
#  <td align="center"><i>DVU0608</i> ←</td>
#  <td align="left">methyl‑accepting chemotaxis protein</td>
#  </tr>
#  <!-- End Table Row -->
#  <!-- Print The Table Row -->
#  <tr class="alternate_table_row_1">
#  <td align="center">NC_002937</td><!-- Seq_Id -->
#  <td align="right">692,683</td><!-- Position -->
#  <td align="center">Δ21 bp</td><!-- Cell Mutation -->
#  <td align="right"></td><td align="right"></td><td align="right"></td><td align="right"></td><td align="right">6.2%</td><td align="right"></td>
#  <td align="center">coding (1140‑1160/1575 nt)</td>
#  <td align="center"><i>DVU0625</i> →</td>
#  <td align="left">cytochrome c nitrite reductase, catalytic subunit NfrA</td>
#  </tr>
#  <!-- End Table Row -->
#  <!-- Print The Table Row -->
#  <tr class="alternate_table_row_0">
#  <td align="center">NC_002937</td><!-- Seq_Id -->
#  <td align="right">705,412</td><!-- Position -->
#  <td align="center">Δ72 bp</td><!-- Cell Mutation -->
#  <td align="right"></td><td align="right"></td><td align="right"></td><td align="right">12.7%</td><td align="right"></td><td align="right"></td>
#  <td align="center">coding (614‑685/1314 nt)</td>
#  <td align="center"><i>DVU0636</i> →</td>
#  <td align="left">response regulator/GGDEF domain‑containing protein</td>
#  </tr>
#  <!-- End Table Row -->
#  <tr>
#  <th>seq id</th>
#  <th>position</th>
#  <th>mutation</th>
#  <th>0</th>
#  <th>UA3-100</th>
#  <th>UA3-300</th>
#  <th>UA3-500</th>
#  <th>UA3-780</th>
#  <th>UA3-1000</th>
#  <th>annotation</th>
#  <th>gene</th>
#  <th width="100%">description</th>
#  </tr>
#  <!-- Print The Table Row -->
#  <tr class="alternate_table_row_1">
#  <td align="center">NC_002937</td><!-- Seq_Id -->
#  <td align="right">708,564</td><!-- Position -->
#  <td align="center">C→T</td><!-- Cell Mutation -->
#  <td align="right"></td><td align="right"></td><td align="right"></td><td align="right">100%</td><td align="right"></td><td align="right"></td>
#  <td align="center"><font class="snp_type_nonsynonymous">M72I</font> (AT<font class="mutation_in_codon">G</font>→AT<font class="mutation_in_codon">A</font>) </td>
#  <td align="center"><i>DVU0638</i> ←</td>
#  <td align="left">hypothetical protein</td>
#  </tr>
#  <!-- End Table Row -->
#  <!-- Print The Table Row -->
#  <tr class="alternate_table_row_0">
#  <td align="center">NC_002937</td><!-- Seq_Id -->
#  <td align="right">716,874</td><!-- Position -->
#  <td align="center">T→A</td><!-- Cell Mutation -->
#  <td align="right">100%</td><td align="right">100%</td><td align="right">100%</td><td align="right">100%</td><td align="right">100%</td><td align="right">100%</td>
#  <td align="center">intergenic (+16/+194)</td>
#  <td align="center"><i>DVU0645</i> → / ← <i>cobI</i></td>
#  <td align="left">methyl‑accepting chemotaxis protein/precorrin‑2 C(20)‑methyltransferase</td>
#  </tr>
#  <!-- End Table Row -->
#  <!-- Print The Table Row -->
#  <tr class="alternate_table_row_1">
#  <td align="center">NC_002937</td><!-- Seq_Id -->
#  <td align="right">727,520</td><!-- Position -->
#  <td align="center">Δ68 bp</td><!-- Cell Mutation -->
#  <td align="right"></td><td align="right">?</td><td align="right"></td><td align="right"></td><td align="right">10.1%</td><td align="right"></td>
#  <td align="center">coding (256‑323/1227 nt)</td>
#  <td align="center"><i>DVU0654</i> ←</td>
#  <td align="left">U32 family peptidase</td>
#  </tr>
#  <!-- End Table Row -->
#  <!-- Print The Table Row -->
#  <tr class="alternate_table_row_0">
#  <td align="center">NC_002937</td><!-- Seq_Id -->
#  <td align="right">728,618</td><!-- Position -->
#  <td align="center">Δ42 bp</td><!-- Cell Mutation -->
#  <td align="right">13.6%</td><td align="right"></td><td align="right"></td><td align="right"></td><td align="right"></td><td align="right"></td>
#  <td align="center">coding
</td><td align="right"></td><td align="right"></td><td align="right"></td>
#  <td align="center"><font class="snp_type_nonsynonymous">D180V</font> (G<font class="mutation_in_codon">A</font>C→G<font class="mutation_in_codon">T</font>C) </td>
#  <td align="center"><i>DVU0799</i> ←</td>
#  <td align="left">hypothetical protein</td>
#  </tr>
#  <!-- End Table Row -->
#  <!-- Print The Table Row -->
#  <tr class="alternate_table_row_1">
#  <td align="center">NC_002937</td><!-- Seq_Id -->
#  <td align="right">885,407</td><!-- Position -->
#  <td align="center">G→A</td><!-- Cell Mutation -->
#  <td align="right"></td><td align="right"></td><td align="right"></td><td align="right"></td><td align="right">55.9%</td><td align="right"></td>
#  <td align="center"><font class="snp_type_nonsense">Q125*</font> (<font class="mutation_in_codon">C</font>AG→<font class="mutation_in_codon">T</font>AG) </td>
#  <td align="center"><i>DVU0799</i> ←</td>
#  <td align="left">hypothetical protein</td>
#  </tr>
#  <!-- End Table Row -->
#  <!-- Print The Table Row -->
#  <tr class="alternate_table_row_0">
#  <td align="center">NC_002937</td><!-- Seq_Id -->
#  <td align="right">896,701</td><!-- Position -->
#  <td align="center">Δ45 bp</td><!-- Cell Mutation -->
#  <td align="right"></td><td align="right"></td><td align="right">35.4%</td><td align="right"></td><td align="right">16.9%</td><td align="right">27.9%</td>
#  <td align="center">coding (561‑605/2061 nt)</td>
#  <td align="center"><i>DVU0810</i> ←</td>
#  <td align="left">hypothetical protein</td>
#  </tr>
#  <!-- End Table Row -->
#  <tr>
#  <th>seq id</th>
#  <th>position</th>
#  <th>mutation</th>
#  <th>0</th>
#  <th>UA3-100</th>
#  <th>UA3-300</th>
#  <th>UA3-500</th>
#  <th>UA3-780</th>
#  <th>UA3-1000</th>
#  <th>annotation</th>
#  <th>gene</th>
#  <th width="100%">description</th>
#  </tr>
#  <!-- Print The Table Row -->
#  <tr class="alternate_table_row_1">
#  <td align="center">NC_002937</td><!-- Seq_Id -->
#  <td align="right">896,707</td><!-- Position -->
#  <td align="center">T→C</td><!-- Cell Mutation -->
#  <td align="right">7.6%</td><td align="right"></td><td align="right">Δ</td><td align="right"></td><td align="right">Δ</td><td align="right">Δ</td>
#  <td align="center"><font class="snp_type_nonsynonymous">D200G</font> (G<font class="mutation_in_codon">A</font>T→G<font class="mutation_in_codon">G</font>T) </td>
#  <td align="center"><i>DVU0810</i> ←</td>
#  <td align="left">hypothetical protein</td>
#  </tr>
#  <!-- End Table Row -->
#  <!-- Print The Table Row -->
#  <tr class="alternate_table_row_0">
#  <td align="center">NC_002937</td><!-- Seq_Id -->
#  <td align="right">896,710</td><!-- Position -->
#  <td align="center">T→A</td><!-- Cell Mutation -->
#  <td align="right">10.0%</td><td align="right"></td><td align="right">Δ</td><td align="right"></td><td align="right">Δ</td><td align="right">Δ</td>
#  <td align="center"><font class="snp_type_nonsynonymous">H199L</font> (C<font class="mutation_in_codon">A</font>C→C<font class="mutation_in_codon">T</font>C) </td>
#  <td align="center"><i>DVU0810</i> ←</td>
#  <td align="left">hypothetical protein</td>
#  </tr>
#  <!-- End Table Row -->
#  <!-- Print The Table Row -->
#  <tr class="alternate_table_row_1">
#  <td align="center">NC_002937</td><!-- Seq_Id -->
#  <td align="right">896,713</td><!-- Position -->
#  <td align="center">T→G</td><!-- Cell Mutation -->
#  <td align="right">9.0%</td><td align="right"></td><td align="right">Δ</td><td align="right"></td><td align="right">Δ</td><td align="right">Δ</td>
#  <td align="center"><font class="snp_type_nonsynonymous">E198A</font> (G<font class="mutation_in_codon">A</font>A→G<font class="mutation_in_codon">C</font>A) </td>
#  <td align="center"><i>DVU0810</i> ←</td>
#  <td align="left">hypothetical protein</td>
#  </tr>
#  <!-- End Table Row -->
#  <!-- Print The Table Row -->
#  <tr class="alternate_table_row_0">
#  <td align="center">NC_002937</td><!-- Seq_Id -->
#  <td align="right">896,724</td><!-- Position -->
#  <td align="center">Δ45 bp</td><!-- Cell Mutation -->
#  <td align="right">25.8%</td><td align="right"></td><td align="right"></td><td align="right"></td><td align="right"></td><td align="right"></td>
#  <td align="center">coding (538‑582/2061 nt)</td>
#  <td align="center"><i>DVU0810</i> ←</td>
#  <td align="left">hypothetical protein</td>
#  </tr>
#  <!-- End Table Row -->
#  <!-- Print The Table Row -->
#  <tr class="alternate_table_row_1">
#  <td align="center">NC_002937</td><!-- Seq_Id -->
#  <td align="right">896,746</td><!-- Position -->
#  <td align="center">T→G</td><!-- Cell Mutation -->
#  <td align="right">Δ</td><td align="right">?</td><td align="right">16.3%</td><td align="right"></td><td align="right"></td><td align="right"></td>
#  <td align="center"><font class="snp_type_nonsynonymous">Q187P</font> (C<font class="mutation_in_codon">A</font>G→C<font class="mutation_in_codon">C</font>G) </td>
#  <td align="center"><i>DVU0810</i> ←</td>
#  <td align="left">hypothetical protein</td>
#  </tr>
#  <!-- End Table Row -->
#  <!-- Print The Table Row -->
#  <tr class="alternate_table_row_0">
#  <td align="center">NC_002937</td><!-- Seq_Id -->
#  <td align="right">896,752</td><!-- Position -->
#  <td align="center">C→T</td><!-- Cell Mutation -->
#  <td align="right">Δ</td><td align="right">?</td><td align="right">10.7%</td><td align="right"></td><td align="right"></td><td align="right"></td>
#  <td align="center"><font class="snp_type_nonsynonymous">R185H</font> (C<font class="mutation_in_codon">G</font>T→C<font class="mutation_in_codon">A</font>T) </td>
#  <td align="center"><i>DVU0810</i> ←</td>
#  <td align="left">hypothetical protein</td>
#  </tr>
#  <!-- End Table Row -->
#  <!-- Print The Table Row -->
#  <tr class="alternate_table_row_1">
#  <td align="center">NC_002937</td><!-- Seq_Id -->
# ...
#  <td align="center">NC_005863</td><!-- Seq_Id -->
#  <td align="right">49,089</td><!-- Position -->
#  <td align="center">G→C</td><!-- Cell Mutation -->
#  <td align="right">100%</td><td align="right"></td><td align="right">100%</td><td align="right"></td><td align="right">100%</td><td align="right">100%</td>
#  <td align="center">intergenic (+7/‑5)</td>
#  <td align="center"><i>DVUA0040</i> → / → <i>DVUA0041</i></td>
#  <td align="left">polysaccharide biosynthesis protein/hypothetical protein</td>
#  </tr>
#  <!-- End Table Row -->
#  <!-- Print The Table Row -->
#  <tr class="alternate_table_row_0">
#  <td align="center">NC_005863</td><!-- Seq_Id -->
#  <td align="right">63,053</td><!-- Position -->
#  <td align="center">Δ123 bp</td><!-- Cell Mutation -->
#  <td align="right"></td><td align="right"></td><td align="right"></td><td align="right"></td><td align="right"></td><td align="right">30.7%</td>
#  <td align="center">coding (555‑677/1389 nt)</td>
#  <td align="center"><i>DVUA0051</i> →</td>
#  <td align="left">glycosyl transferase, group 1 family protein</td>
#  </tr>
#  <!-- End Table Row -->
#  <tr>
#  <th>seq id</th>
#  <th>position</th>
#  <th>mutation</th>
#  <th>0</th>
#  <th>UA3-100</th>
#  <th>UA3-300</th>
#  <th>UA3-500</th>
#  <th>UA3-780</th>
#  <th>UA3-1000</th>
#  <th>annotation</th>
#  <th>gene</th>
#  <th width="100%">description</th>
#  </tr>
#  <!-- Print The Table Row -->
#  <tr class="alternate_table_row_1">
#  <td align="center">NC_005863</td><!-- Seq_Id -->
#  <td align="right">73,412</td><!-- Position -->
#  <td align="center">Δ66 bp</td><!-- Cell Mutation -->
#  <td align="right"></td><td align="right"></td><td align="right"></td><td align="right"></td><td align="right
</td>
#  <td align="center"><i>DVUA0135</i> → / ← <i>zupT</i></td>
#  <td align="left">CRISPR‑associated Cas2 family protein/zinc transporter ZupT</td>
#  </tr>
#  <!-- End Table Row -->
#  <!-- Print The Table Row -->
#  <tr class="alternate_table_row_0">
#  <td align="center">NC_005863</td><!-- Seq_Id -->
#  <td align="right">176,659</td><!-- Position -->
#  <td align="center">Δ65 bp</td><!-- Cell Mutation -->
#  <td align="right">35.3%</td><td align="right"></td><td align="right"></td><td align="right"></td><td align="right"></td><td align="right"></td>
#  <td align="center">intergenic (+940/+1105)</td>
#  <td align="center"><i>DVUA0135</i> → / ← <i>zupT</i></td>
#  <td align="left">CRISPR‑associated Cas2 family protein/zinc transporter ZupT</td>
#  </tr>
#  <!-- End Table Row -->
#  <!-- Print The Table Row -->
#  <tr class="alternate_table_row_1">
#  <td align="center">NC_005863</td><!-- Seq_Id -->
#  <td align="right">176,922</td><!-- Position -->
#  <td align="center">Δ131 bp</td><!-- Cell Mutation -->
#  <td align="right"></td><td align="right"></td><td align="right"></td><td align="right"></td><td align="right"></td><td align="right">10.1%</td>
#  <td align="center">intergenic (+1203/+776)</td>
#  <td align="center"><i>DVUA0135</i> → / ← <i>zupT</i></td>
#  <td align="left">CRISPR‑associated Cas2 family protein/zinc transporter ZupT</td>
#  </tr>
#  <!-- End Table Row -->
#  <!-- Print The Table Row -->
#  <tr class="alternate_table_row_0">
#  <td align="center">NC_005863</td><!-- Seq_Id -->
#  <td align="right">176,923</td><!-- Position -->
#  <td align="center">Δ66 bp</td><!-- Cell Mutation -->
#  <td align="right"></td><td align="right"></td><td align="right">8.8%</td><td align="right"></td><td align="right"></td><td align="right">Δ</td>
#  <td align="center">intergenic (+1204/+840)</td>
#  <td align="center"><i>DVUA0135</i> → / ← <i>zupT</i></td>
#  <td align="left">CRISPR‑associated Cas2 family protein/zinc transporter ZupT</td>
#  </tr>
#  <!-- End Table Row -->
#  <!-- Print The Table Row -->
#  <tr class="alternate_table_row_1">
#  <td align="center">NC_005863</td><!-- Seq_Id -->
#  <td align="right">176,988</td><!-- Position -->
#  <td align="center">Δ65 bp</td><!-- Cell Mutation -->
#  <td align="right">25.9%</td><td align="right"></td><td align="right">15.5%</td><td align="right"></td><td align="right"></td><td align="right">Δ</td>
#  <td align="center">intergenic (+1269/+776)</td>
#  <td align="center"><i>DVUA0135</i> → / ← <i>zupT</i></td>
#  <td align="left">CRISPR‑associated Cas2 family protein/zinc transporter ZupT</td>
#  </tr>
#  <!-- End Table Row -->
#  <!-- Print The Table Row -->
#  <tr class="alternate_table_row_0">
#  <td align="center">NC_005863</td><!-- Seq_Id -->
#  <td align="right">177,053</td><!-- Position -->
#  <td align="center">Δ65 bp</td><!-- Cell Mutation -->
#  <td align="right">15.2%</td><td align="right"></td><td align="right"></td><td align="right"></td><td align="right"></td><td align="right"></td>
#  <td align="center">intergenic (+1334/+711)</td>
#  <td align="center"><i>DVUA0135</i> → / ← <i>zupT</i></td>
#  <td align="left">CRISPR‑associated Cas2 family protein/zinc transporter ZupT</td>
#  </tr>
#  <!-- End Table Row -->
#  <tr>
#  <th>seq id</th>
#  <th>position</th>
#  <th>mutation</th>
#  <th>0</th>
#  <th>UA3-100</th>
#  <th>UA3-300</th>
#  <th>UA3-500</th>
#  <th>UA3-780</th>
#  <th>UA3-1000</th>
#  <th>annotation</th>
#  <th>gene</th>
#  <th width="100%">description</th>
#  </tr>
#  <!-- Print The Table Row -->
#  <tr class="alternate_table_row_1">
#  <td align="center">NC_005863</td><!-- Seq_Id -->
#  <td align="right">177,184</td><!-- Position -->
#  <td align="center">Δ66 bp</td><!-- Cell Mutation -->
#  <td align="right">8.0%</td><td align="right"></td><td align="right"></td><td align="right"></td><td align="right"></td><td align="right"></td>
#  <td align="center">intergenic (+1465/+579)</td>
#  <td align="center"><i>DVUA0135</i> → / ← <i>zupT</i></td>
#  <td align="left">CRISPR‑associated Cas2 family protein/zinc transporter ZupT</td>
#  </tr>
#  <!-- End Table Row -->
#  <!-- Print The Table Row -->
#  <tr class="alternate_table_row_0">
#  <td align="center">NC_005863</td><!-- Seq_Id -->
#  <td align="right">177,314</td><!-- Position -->
#  <td align="center">Δ66 bp</td><!-- Cell Mutation -->
#  <td align="right">14.7%</td><td align="right"></td><td align="right"></td><td align="right"></td><td align="right"></td><td align="right"></td>
#  <td align="center">intergenic (+1595/+449)</td>
#  <td align="center"><i>DVUA0135</i> → / ← <i>zupT</i></td>
#  <td align="left">CRISPR‑associated Cas2 family protein/zinc transporter ZupT</td>
#  </tr>
#  <!-- End Table Row -->
#  <!-- Print The Table Row -->
#  <tr class="alternate_table_row_1">
#  <td align="center">NC_005863</td><!-- Seq_Id -->
#  <td align="right">193,777</td><!-- Position -->
#  <td align="center">Δ30 bp</td><!-- Cell Mutation -->
#  <td align="right"></td><td align="right"></td><td align="right"></td><td align="right"></td><td align="right">8.0%</td><td align="right"></td>
#  <td align="center">coding (195‑224/3018 nt)</td>
#  <td align="center"><i>DVUA0148</i> →</td>
#  <td align="left">major facilitator superfamily protein</td>
#  </tr>
#  <!-- End Table Row -->
#  <!-- Print The Table Row -->
#  <tr class="alternate_table_row_0">
#  <td align="center">NC_005863</td><!-- Seq_Id -->
#  <td align="right">195,165</td><!-- Position -->
#  <td align="center">Δ72 bp</td><!-- Cell Mutation -->
#  <td align="right"></td><td align="right"></td><td align="right"></td><td align="right"></td><td align="right"></td><td align="right">6.5%</td>
#  <td align="center">coding (1583‑1654/3018 nt)</td>
#  <td align="center"><i>DVUA0148</i> →</td>
#  <td align="left">major facilitator superfamily protein</td>
#  </tr>
#  <!-- End Table Row -->
#  <!-- Print The Table Row -->
#  <tr class="alternate_table_row_1">
#  <td align="center">NC_005863</td><!-- Seq_Id -->
#  <td align="right">196,980</td><!-- Position -->
#  <td align="center">Δ81 bp</td><!-- Cell Mutation -->
#  <td align="right"></td><td align="right"></td><td align="right"></td><td align="right"></td><td align="right">15.8%</td><td align="right"></td>
#  <td align="center">coding (349‑429/1785 nt)</td>
#  <td align="center"><i>DVUA0149</i> →</td>
#  <td align="left">hypothetical protein</td>
#  </tr>
#  <!-- End Table Row -->
#  </table></body></html></html>]

# %%
import numpy as np
import pandas as pd
import re
UA3_100 = pd.read_table('/Users/ymseah/Documents/sic_UA3-15_breseq/annotated.gd', comment='#', names=range(50), dtype=str)
UA3_100.insert(0, 'generation', 100)
UA3_300 = pd.read_table('/Users/ymseah/Documents/sic_UA3.45_breseq/annotated.gd', comment='#', names=range(50), dtype=str)
UA3_300.insert(0, 'generation', 300)
UA3_500 = pd.read_table('/Users/ymseah/Documents/sic_UA3-76_breseq/annotated.gd', comment='#', names=range(50), dtype=str)
UA3_500.insert(0, 'generation', 500)
UA3_780 = pd.read_table('/Users/ymseah/Documents/sic_UA3.118_breseq/annotated.gd', comment='#', names=range(50), dtype=str)
UA3_780.insert(0, 'generation', 780)
UA3_1000 = pd.read_table('/Users/ymseah/Documents/sic_UA3_S2_L001_breseq/output/evidence/annotated.gd', comment='#', names=range(50), dtype=str)
UA3_1000.insert(0, 'generation', 1000)

UA3_df  = pd.concat([UA3_100, UA3_300, UA3_500, UA3_780, UA3_1000], ignore_index=True)
UA3_df.insert(0, 'line', 'UA3')
UA3_df.insert(2, 'frequency', 0.0)
UA3_df.insert(3, 'gene_product', '')
UA3_df.insert(4, 'gene_position', '')
UA3_df.insert(5, 'reject', '')

# %%
for row in UA3_df.itertuples():
    #check each column
    col_index = 6
    while col_index < 50:
        #1. polymorphism frequencies
        if re.match('frequency=', str(UA3_df.loc[row[0], col_index])):
            UA3_df.loc[row[0], 'frequency'] = re.sub('frequency=', '', str(UA3_df.loc[row[0], col_index]))
        #2. gene products
        elif re.match('gene_product=', str(UA3_df.loc[row[0], col_index])):
            UA3_df.loc[row[0], 'gene_product'] = re.sub('gene_product=', '', str(UA3_df.loc[row[0], col_index]))
        #3. polymorphism rejection reasons
        elif re.match('reject=', str(UA3_df.loc[row[0], col_index])):
            UA3_df.loc[row[0], 'reject'] = re.sub('reject=', '', str(UA3_df.loc[row[0], col_index]))
        #4. gene annotations
        elif re.match('gene_position=', str(UA3_df.loc[row[0], col_index])):
            UA3_df.loc[row[0], 'gene_position'] = re.sub('gene_position=', '', str(UA3_df.loc[row[0], col_index]))
        col_index += 1
    #set frequencies type to float
    if re.match('1|2|3|4|5|6|7|8|9', str(UA3_df.loc[row[0], 'frequency'])):
        UA3_df.loc[row[0], 'frequency'] = float(UA3_df.loc[row[0], 'frequency'])
    else:
        UA3_df.loc[row[0], 'frequency'] = 0.0
    #set positions (col 4) type to int
    UA3_df.loc[row[0], 4] = int(UA3_df.loc[row[0], 4])
    #set reject col to 'NA' when no reject reason given.
    if (UA3_df.loc[row[0], 'reject'] == '') & (UA3_df.loc[row[0], 2] == '.'):
        UA3_df.loc[row[0], 'reject'] = 'NA'

# %%
UA3_df.rename(columns = {0: 'entry_type', 1: 'item_id', 2: 'evidence_ids', 3: 'ref_genome', 4:'position'}, inplace=True)
ua3df_sub = UA3_df[['line', 'generation', 'frequency', 'gene_product', 'gene_position', 'reject', 'entry_type', 'item_id', 'evidence_ids', 'ref_genome', 'position']].copy()
ua3df_sub.to_csv('/Users/ymseah/Documents/ua3.csv', index=False)
# Out:
#       line  generation  frequency  \
# 0      UA3         100          1
# 1      UA3         100          1
# 2      UA3         100          1
# 3      UA3         100          1
# 4      UA3         100          1
# 5      UA3         100          1
# 6      UA3         100          1
# 7      UA3         100          1
# 8      UA3         100          1
# 9      UA3         100          1
# 10     UA3         100          1
# 11     UA3         100          1
# 12     UA3         100          1
# 13     UA3         100          1
# 14     UA3         100          1
# 15     UA3         100          1
# 16     UA3         100          1
# 17     UA3         100          1
# 18     UA3         100          1
# 19     UA3         100          1
# 20     UA3         100          1
# 21     UA3         100          1
# 22     UA3         100   0.180326
# 23     UA3         100  0.0668367
# 24     UA3         100  0.0547867
# 25     UA3         100  0.0638256
# 26     UA3         100  0.0554952
# 27     UA3         100          1
# 28     UA3         100   0.060699
# 29     UA3         100  0.0878735
# ...    ...         ...        ...
# 46546  UA3        1000          0
# 46547  UA3        1000          0
# 46548  UA3        1000          0
# 46549  UA3        1000          0
# 46550  UA3        1000          0
# 46551  UA3        1000          0
# 46552  UA3        1000          0
# 46553  UA3        1000          0
# 46554  UA3        1000          0
# 46555  UA3        1000          0
# 46556  UA3        1000          0
# 46557  UA3        1000          0
# 46558  UA3        1000          0
# 46559  UA3        1000          0
# 46560  UA3        1000          0
# 46561  UA3        1000          0
# 46562  UA3        1000          0
# 46563  UA3        1000          0
# 46564  UA3        1000          0
# 46565  UA3        1000          0
# 46566  UA3        1000          0
# 46567  UA3        1000          0
# 46568  UA3        1000          0
# 46569  UA3        1000          0
# 46570  UA3        1000          0
# 46571  UA3        1000          0
# 46572  UA3        1000          0
# 46573  UA3        1000          0
# 46574  UA3        1000          0
# 46575  UA3        1000          0
#
#                                             gene_product  \
# 0              hypothetical protein/hypothetical protein
# 1      oligopeptide/dipeptide ABC transporter peripla...
# 2      ISDvu4, transposase, truncation/glyceraldehyde...
# 3      methyl-accepting chemotaxis protein/precorrin-...
# 4          histidinol dehydrogenase/hypothetical protein
# 5              hypothetical protein/hypothetical protein
# 6                    geranylgeranyl diphosphate synthase
# 7                                   hypothetical protein
# 8                                   hypothetical protein
# 9                                            lipoprotein
# 10             hypothetical protein/hypothetical protein
# 11                                  hypothetical protein
# 12                 protein-glutamate methylesterase CheB
# 13                              hydrogenase subunit CooK
# 14             hypothetical protein/hypothetical protein
# 15       hypothetical protein/glutaminyl-tRNA synthetase
# 16                                  hypothetical protein
# 17     hypothetical protein/sigma-54 dependent transc...
# 18       sensory box histidine kinase/response regulator
# 19     sigma-54 dependent DNA-binding response regulator
# 20     nicotinate-nucleotide--dimethylbenzimidazole p...
# 21        hypothetical protein/ADP-ribosylglycohydrolase
# 22                       DNA polymerase II small subunit
# 23                                       ABC transporter
# 24                                  hypothetical protein
# 25                                  hypothetical protein
# 26                                  hypothetical protein
# 27                                  hypothetical protein
# 28                                  transcription factor
# 29                                  hypothetical protein
# ...                                                  ...
# 46546
# 46547
# 46548
# 46549
# 46550
# 46551
# 46552
# 46553
# 46554
# 46555
# 46556
# 46557
# 46558
# 46559
# 46560
# 46561
# 46562
# 46563
# 46564
# 46565
# 46566
# 46567
# 46568
# 46569
# 46570
# 46571
# 46572
# 46573
# 46574
# 46575
#
#                     gene_position reject entry_type item_id evidence_ids  \
# 0           intergenic (-125/+57)               INS       1          109
# 1           intergenic (-395/-38)               INS       2          110
# 2           intergenic (-61/+148)               MOB       3    1494,1495
# 3           intergenic (+16/+194)               SNP       4          112
# 4            intergenic (-96/+34)               DEL       5          113
# 5           intergenic (+125/+43)               INS       6          116
# 6                             122               SNP       7          117
# 7                             316               SNP       8          118
# 8             coding (227/486 nt)               DEL       9          119
# 9                             304               SNP      10          120
# 10        intergenic (-562/-1089)               INS      11          124
# 11                            504               SNP      12          125
# 12                           1078               SNP      13          126
# 13                            824               SNP      14          127
# 14           intergenic (-198/+9)               SNP      15          128
# 15        intergenic (+1321/-560)               INS      16          131
# 16          coding (23-24/144 nt)               SUB      17      132,133
# 17           intergenic (+53/-32)               INS      18         1497
# 18     coding (2061-2062/3420 nt)               DEL      19      134,135
# 19                            266               SNP      20          138
# 20         intergenic (+439/-763)               INS      21          139
# 21          intergenic (+165/+70)               INS      22         1498
# 22       coding (290-370/1758 nt)               DEL      23         1502
# 23        coding (446-535/762 nt)               DEL      24         1510
# 24                            288               SNP      25          147
# 25                            291               SNP      26          148
# 26         coding (98-115/234 nt)               DEL      27         1513
# 27                            406               SNP      28          153
# 28                            390               SNP      29          158
# 29                            468               SNP      30          165
# ...                           ...    ...        ...     ...          ...
# 46546                                 NA         UN    1162            .
# 46547                                 NA         UN    1163            .
# 46548                                 NA         UN    1164            .
# 46549                                 NA         UN    1165            .
# 46550                                 NA         UN    1166            .
# 46551                                 NA         UN    1167            .
# 46552                                 NA         UN    1168            .
# 46553                                 NA         UN    1169            .
# 46554                                 NA         UN    1170            .
# 46555                                 NA         UN    1171            .
# 46556                                 NA         UN    1172            .
# 46557                                 NA         UN    1173            .
# 46558                                 NA         UN    1174            .
# 46559                                 NA         UN    1175            .
# 46560                                 NA         UN    1176            .
# 46561                                 NA         UN    1177            .
# 46562                                 NA         UN    1178            .
# 46563                                 NA         UN    1179            .
# 46564                                 NA         UN    1180            .
# 46565                                 NA         UN    1181            .
# 46566                                 NA         UN    1182            .
# 46567                                 NA         UN    1183            .
# 46568                                 NA         UN    1184            .
# 46569                                 NA         UN    1185            .
# 46570                                 NA         UN    1186            .
# 46571                                 NA         UN    1187            .
# 46572                                 NA         UN    1188            .
# 46573                                 NA         UN    1189            .
# 46574                                 NA         UN    1190            .
# 46575                                 NA         UN    1191            .
#
#       ref_genome position
# 0      NC_002937    42867
# 1      NC_002937   211389
# 2      NC_002937   629936
# 3      NC_002937   716874
# 4      NC_002937   882512
# 5      NC_002937  1313341
# 6      NC_002937  1426830
# 7      NC_002937  1773256
# 8      NC_002937  1773345
# 9      NC_002937  1913197
# 10     NC_002937  2083305
# 11     NC_002937  2104739
# 12     NC_002937  2162235
# 13     NC_002937  2381877
# 14     NC_002937  2502193
# 15     NC_002937  3056212
# 16     NC_002937  3064064
# 17     NC_002937  3066926
# 18     NC_002937  3140577
# 19     NC_002937  3142198
# 20     NC_002937  3455727
# 21     NC_002937  3457155
# 22     NC_005791    18990
# 23     NC_005791   173904
# 24     NC_005791   198319
# 25     NC_005791   198322
# 26     NC_005791   211265
# 27     NC_005791   241892
# 28     NC_005791   259095
# 29     NC_005791   277770
# ...          ...      ...
# 46546  NC_002937  2440415
# 46547  NC_002937  2519429
# 46548  NC_002937  2559754
# 46549  NC_002937  2693160
# 46550  NC_002937  2693162
# 46551  NC_002937  2694912
# 46552  NC_002937  2696429
# 46553  NC_002937  2956045
# 46554  NC_002937  3247196
# 46555  NC_002937  3251432
# 46556  NC_002937  3252065
# 46557  NC_002937  3252067
# 46558  NC_002937  3252069
# 46559  NC_002937  3252071
# 46560  NC_002937  3252074
# 46561  NC_002937  3252079
# 46562  NC_002937  3252082
# 46563  NC_005791        1
# 46564  NC_005791      254
# 46565  NC_005791     9726
# 46566  NC_005791     9733
# 46567  NC_005791     9736
# 46568  NC_005791    37393
# 46569  NC_005791    37396
# 46570  NC_005791    41249
# 46571  NC_005791   735724
# 46572  NC_005791   735729
# 46573  NC_005791  1124421
# 46574  NC_005791  1125840
# 46575  NC_005863    99978
#
# [46576 rows x 11 columns]
